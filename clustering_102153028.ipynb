# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# **USING K-MEANS CLUSTERING**

# %%
from pycaret.clustering import *
import pandas as pd
from prettytable import PrettyTable

pt = PrettyTable()
myDataSet = pd.read_csv("/content/tripadvisor_review.csv")
kMeanClusteringParameters = setup(data=myDataSet, verbose=False)

num_clusters = [3, 4, 5]
svalues = []
cvalues = []
dvalues = []

def get_parameters(num_clusters):
    model = create_model('kmeans', num_clusters=num_clusters)
    prediction = assign_model(model)
    performance = pull()
    svalues.append(performance['Silhouette'][0])
    cvalues.append(performance['Calinski-Harabasz'][0])
    dvalues.append(performance['Davies-Bouldin'][0])

def get_ans():
  for num in num_clusters:
    get_parameters(num)

print("For no data processing")
get_ans()
print("For using normalisation")
normparam = setup(data=myDataSet,normalize = True, normalize_method = 'zscore', verbose=False)
get_ans()
print("For using transform")
transformparam=setup(data=myDataSet,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using PCA")
pcaparam=setup(data=myDataSet,transformation = True,pca = True, pca_method = 'linear', verbose=False)
get_ans()
print("For using N+T")
ntparam=setup(data=myDataSet,transformation = True, normalize = True,normalize_method = 'zscore',
      transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using N+T+PCA")
ntpcaparam=setup(data=myDataSet,transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear',  verbose=False)
get_ans()
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_90290" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90290_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90290_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90290_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90290_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90290_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90290_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90290_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90290_row0_col0" class="data row0 col0" >0.1372</td>
#       <td id="T_90290_row0_col1" class="data row0 col1" >163.8226</td>
#       <td id="T_90290_row0_col2" class="data row0 col2" >2.3531</td>
#       <td id="T_90290_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_90290_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_90290_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_b2702" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2702_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b2702_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b2702_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b2702_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b2702_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b2702_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2702_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2702_row0_col0" class="data row0 col0" >0.0868</td>
#       <td id="T_b2702_row0_col1" class="data row0 col1" >130.5334</td>
#       <td id="T_b2702_row0_col2" class="data row0 col2" >2.8170</td>
#       <td id="T_b2702_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b2702_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b2702_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_fb9cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb9cf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fb9cf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fb9cf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fb9cf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fb9cf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fb9cf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb9cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb9cf_row0_col0" class="data row0 col0" >0.0818</td>
#       <td id="T_fb9cf_row0_col1" class="data row0 col1" >110.9388</td>
#       <td id="T_fb9cf_row0_col2" class="data row0 col2" >2.6514</td>
#       <td id="T_fb9cf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fb9cf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fb9cf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalisation
# <style type="text/css">
# </style>
# <table id="T_30553" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30553_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_30553_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_30553_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_30553_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_30553_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_30553_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30553_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30553_row0_col0" class="data row0 col0" >0.0014</td>
#       <td id="T_30553_row0_col1" class="data row0 col1" >2.2237</td>
#       <td id="T_30553_row0_col2" class="data row0 col2" >16.8066</td>
#       <td id="T_30553_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_30553_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_30553_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_3eb46" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eb46_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3eb46_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3eb46_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3eb46_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3eb46_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3eb46_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eb46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3eb46_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_3eb46_row0_col1" class="data row0 col1" >1.9073</td>
#       <td id="T_3eb46_row0_col2" class="data row0 col2" >17.7968</td>
#       <td id="T_3eb46_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3eb46_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3eb46_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_053ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_053ea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_053ea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_053ea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_053ea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_053ea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_053ea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_053ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_053ea_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_053ea_row0_col1" class="data row0 col1" >1.7529</td>
#       <td id="T_053ea_row0_col2" class="data row0 col2" >16.2882</td>
#       <td id="T_053ea_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_053ea_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_053ea_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using transform
# <style type="text/css">
# </style>
# <table id="T_5c1e5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c1e5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5c1e5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5c1e5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5c1e5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5c1e5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5c1e5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c1e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c1e5_row0_col0" class="data row0 col0" >0.2343</td>
#       <td id="T_5c1e5_row0_col1" class="data row0 col1" >426.2680</td>
#       <td id="T_5c1e5_row0_col2" class="data row0 col2" >1.4069</td>
#       <td id="T_5c1e5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5c1e5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5c1e5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_4f93a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f93a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4f93a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4f93a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4f93a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4f93a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4f93a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f93a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f93a_row0_col0" class="data row0 col0" >0.2500</td>
#       <td id="T_4f93a_row0_col1" class="data row0 col1" >417.2256</td>
#       <td id="T_4f93a_row0_col2" class="data row0 col2" >1.2622</td>
#       <td id="T_4f93a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4f93a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4f93a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_fc24a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc24a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc24a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc24a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc24a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc24a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc24a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc24a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc24a_row0_col0" class="data row0 col0" >0.2213</td>
#       <td id="T_fc24a_row0_col1" class="data row0 col1" >363.3798</td>
#       <td id="T_fc24a_row0_col2" class="data row0 col2" >1.3654</td>
#       <td id="T_fc24a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fc24a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fc24a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using PCA
# <style type="text/css">
# </style>
# <table id="T_cee2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cee2d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cee2d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cee2d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cee2d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cee2d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cee2d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cee2d_row0_col0" class="data row0 col0" >0.2322</td>
#       <td id="T_cee2d_row0_col1" class="data row0 col1" >426.2803</td>
#       <td id="T_cee2d_row0_col2" class="data row0 col2" >1.4052</td>
#       <td id="T_cee2d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cee2d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cee2d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a2da8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2da8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a2da8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a2da8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a2da8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a2da8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a2da8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2da8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2da8_row0_col0" class="data row0 col0" >0.2513</td>
#       <td id="T_a2da8_row0_col1" class="data row0 col1" >417.3842</td>
#       <td id="T_a2da8_row0_col2" class="data row0 col2" >1.2435</td>
#       <td id="T_a2da8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a2da8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a2da8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_64f79" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64f79_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_64f79_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_64f79_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_64f79_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_64f79_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_64f79_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64f79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64f79_row0_col0" class="data row0 col0" >0.2234</td>
#       <td id="T_64f79_row0_col1" class="data row0 col1" >363.3091</td>
#       <td id="T_64f79_row0_col2" class="data row0 col2" >1.3454</td>
#       <td id="T_64f79_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_64f79_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_64f79_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T
# <style type="text/css">
# </style>
# <table id="T_b0859" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0859_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b0859_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b0859_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b0859_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b0859_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b0859_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0859_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0859_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_b0859_row0_col1" class="data row0 col1" >2.0495</td>
#       <td id="T_b0859_row0_col2" class="data row0 col2" >18.8334</td>
#       <td id="T_b0859_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b0859_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b0859_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_f9583" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9583_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f9583_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f9583_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f9583_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f9583_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f9583_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9583_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9583_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_f9583_row0_col1" class="data row0 col1" >1.8145</td>
#       <td id="T_f9583_row0_col2" class="data row0 col2" >17.3238</td>
#       <td id="T_f9583_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f9583_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f9583_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_8d766" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d766_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8d766_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8d766_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8d766_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8d766_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8d766_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d766_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d766_row0_col0" class="data row0 col0" >0.0005</td>
#       <td id="T_8d766_row0_col1" class="data row0 col1" >1.6476</td>
#       <td id="T_8d766_row0_col2" class="data row0 col2" >16.6636</td>
#       <td id="T_8d766_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8d766_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8d766_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T+PCA
# <style type="text/css">
# </style>
# <table id="T_5b0a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b0a2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5b0a2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5b0a2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5b0a2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5b0a2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5b0a2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b0a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b0a2_row0_col0" class="data row0 col0" >0.0010</td>
#       <td id="T_5b0a2_row0_col1" class="data row0 col1" >1.9824</td>
#       <td id="T_5b0a2_row0_col2" class="data row0 col2" >19.0993</td>
#       <td id="T_5b0a2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5b0a2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5b0a2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a354c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a354c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a354c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a354c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a354c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a354c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a354c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a354c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a354c_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_a354c_row0_col1" class="data row0 col1" >1.7578</td>
#       <td id="T_a354c_row0_col2" class="data row0 col2" >17.3801</td>
#       <td id="T_a354c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a354c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a354c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_6893e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6893e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6893e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6893e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6893e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6893e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6893e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6893e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6893e_row0_col0" class="data row0 col0" >0.0005</td>
#       <td id="T_6893e_row0_col1" class="data row0 col1" >1.5969</td>
#       <td id="T_6893e_row0_col2" class="data row0 col2" >16.6017</td>
#       <td id="T_6893e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6893e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6893e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pt.field_names=["Parameters","No data preprocessing c=3","No data preprocessing c=4 ","No data preprocessing c=5","Using Normalisation c=3","Using Normalisation c=4","Using Normalisation c=5","Using Transform c=3","Using Transform c=4","Using Transform c=5","Using PCA c=3","Using PCA c=4","Using PCA c=5","Using N+T c=3","Using N+T c=4","Using N+T c=5","Using N+T+PCA c=3","Using N+T+PCA c=4","Using N+T+PCA c=5"]
pt.add_row(["Silhouette",*svalues])
pt.add_row(["Calinski-Harabasz",*cvalues])
pt.add_row(["Davies-Bouldin",*dvalues])
print("USING K-MEANS CLUSTERING")
print(pt)
# Out:
# USING K-MEANS CLUSTERING
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+
# |     Parameters    | No data preprocessing c=3 | No data preprocessing c=4  | No data preprocessing c=5 | Using Normalisation c=3 | Using Normalisation c=4 | Using Normalisation c=5 | Using Transform c=3 | Using Transform c=4 | Using Transform c=5 | Using PCA c=3 | Using PCA c=4 | Using PCA c=5 | Using N+T c=3 | Using N+T c=4 | Using N+T c=5 | Using N+T+PCA c=3 | Using N+T+PCA c=4 | Using N+T+PCA c=5 |
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+
# |     Silhouette    |           0.1372          |           0.0868           |           0.0818          |          0.0014         |          0.0009         |          0.0007         |        0.2343       |         0.25        |        0.2213       |     0.2322    |     0.2513    |     0.2234    |     0.0009    |     0.0007    |     0.0005    |       0.001       |       0.0007      |       0.0005      |
# | Calinski-Harabasz |          163.8226         |          130.5334          |          110.9388         |          2.2237         |          1.9073         |          1.7529         |       426.268       |       417.2256      |       363.3798      |    426.2803   |    417.3842   |    363.3091   |     2.0495    |     1.8145    |     1.6476    |       1.9824      |       1.7578      |       1.5969      |
# |   Davies-Bouldin  |           2.3531          |           2.817            |           2.6514          |         16.8066         |         17.7968         |         16.2882         |        1.4069       |        1.2622       |        1.3654       |     1.4052    |     1.2435    |     1.3454    |    18.8334    |    17.3238    |    16.6636    |      19.0993      |      17.3801      |      16.6017      |
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+

# %%
# To save output as .csv file
import csv

with open("kmeans_output.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(pt.field_names)
    for row in pt._rows:
        writer.writerow(row)

# %% [markdown]
# **USING HIERARCHIAL CLUSTERING**

# %%
from pycaret.clustering import *
import pandas as pd
from prettytable import PrettyTable

pt2 = PrettyTable()
myDataSet = pd.read_csv("/content/tripadvisor_review.csv")
kMeanClusteringParameters = setup(data=myDataSet, verbose=False)

num_clusters = [3, 4, 5]
svalues = []
cvalues = []
dvalues = []

def get_parameters(num_clusters):
    model = create_model('hclust', num_clusters=num_clusters)
    prediction = assign_model(model)
    performance = pull()
    svalues.append(performance['Silhouette'][0])
    cvalues.append(performance['Calinski-Harabasz'][0])
    dvalues.append(performance['Davies-Bouldin'][0])

def get_ans():
  for num in num_clusters:
    get_parameters(num)

print("For no data processing")
get_ans()
print("For using normalisation")
normparam = setup(data=myDataSet,normalize = True, normalize_method = 'zscore', verbose=False)
get_ans()
print("For using transform")
transformparam=setup(data=myDataSet,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using PCA")
pcaparam=setup(data=myDataSet,transformation = True,pca = True, pca_method = 'linear', verbose=False)
get_ans()
print("For using N+T")
ntparam=setup(data=myDataSet,transformation = True, normalize = True,normalize_method = 'zscore',
      transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using N+T+PCA")
ntpcaparam=setup(data=myDataSet,transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear',  verbose=False)
get_ans()
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_446e7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_446e7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_446e7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_446e7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_446e7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_446e7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_446e7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_446e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_446e7_row0_col0" class="data row0 col0" >0.1298</td>
#       <td id="T_446e7_row0_col1" class="data row0 col1" >141.6293</td>
#       <td id="T_446e7_row0_col2" class="data row0 col2" >2.5243</td>
#       <td id="T_446e7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_446e7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_446e7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_95d84" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95d84_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95d84_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95d84_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95d84_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95d84_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95d84_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95d84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95d84_row0_col0" class="data row0 col0" >0.0697</td>
#       <td id="T_95d84_row0_col1" class="data row0 col1" >113.4169</td>
#       <td id="T_95d84_row0_col2" class="data row0 col2" >2.9151</td>
#       <td id="T_95d84_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95d84_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95d84_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_17e09" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17e09_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_17e09_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_17e09_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_17e09_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_17e09_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_17e09_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17e09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17e09_row0_col0" class="data row0 col0" >0.0607</td>
#       <td id="T_17e09_row0_col1" class="data row0 col1" >98.4764</td>
#       <td id="T_17e09_row0_col2" class="data row0 col2" >2.8817</td>
#       <td id="T_17e09_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_17e09_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_17e09_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalisation
# <style type="text/css">
# </style>
# <table id="T_6676a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6676a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6676a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6676a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6676a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6676a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6676a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6676a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6676a_row0_col0" class="data row0 col0" >0.0020</td>
#       <td id="T_6676a_row0_col1" class="data row0 col1" >2.1931</td>
#       <td id="T_6676a_row0_col2" class="data row0 col2" >14.3736</td>
#       <td id="T_6676a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6676a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6676a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_d77a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d77a8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d77a8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d77a8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d77a8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d77a8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d77a8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d77a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d77a8_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_d77a8_row0_col1" class="data row0 col1" >1.9435</td>
#       <td id="T_d77a8_row0_col2" class="data row0 col2" >16.7015</td>
#       <td id="T_d77a8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d77a8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d77a8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a57c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a57c5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a57c5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a57c5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a57c5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a57c5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a57c5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a57c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a57c5_row0_col0" class="data row0 col0" >0.0008</td>
#       <td id="T_a57c5_row0_col1" class="data row0 col1" >1.8057</td>
#       <td id="T_a57c5_row0_col2" class="data row0 col2" >16.0352</td>
#       <td id="T_a57c5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a57c5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a57c5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using transform
# <style type="text/css">
# </style>
# <table id="T_f4280" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4280_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f4280_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f4280_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f4280_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f4280_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f4280_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4280_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4280_row0_col0" class="data row0 col0" >0.1931</td>
#       <td id="T_f4280_row0_col1" class="data row0 col1" >344.3767</td>
#       <td id="T_f4280_row0_col2" class="data row0 col2" >1.5753</td>
#       <td id="T_f4280_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f4280_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f4280_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_19ee2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19ee2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_19ee2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_19ee2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_19ee2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_19ee2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_19ee2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19ee2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19ee2_row0_col0" class="data row0 col0" >0.2179</td>
#       <td id="T_19ee2_row0_col1" class="data row0 col1" >332.9163</td>
#       <td id="T_19ee2_row0_col2" class="data row0 col2" >1.4285</td>
#       <td id="T_19ee2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_19ee2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_19ee2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_887b3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_887b3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_887b3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_887b3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_887b3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_887b3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_887b3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_887b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_887b3_row0_col0" class="data row0 col0" >0.1710</td>
#       <td id="T_887b3_row0_col1" class="data row0 col1" >298.0764</td>
#       <td id="T_887b3_row0_col2" class="data row0 col2" >1.5761</td>
#       <td id="T_887b3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_887b3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_887b3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using PCA
# <style type="text/css">
# </style>
# <table id="T_3f6ab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f6ab_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3f6ab_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3f6ab_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3f6ab_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3f6ab_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3f6ab_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f6ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f6ab_row0_col0" class="data row0 col0" >0.1931</td>
#       <td id="T_3f6ab_row0_col1" class="data row0 col1" >344.3767</td>
#       <td id="T_3f6ab_row0_col2" class="data row0 col2" >1.5753</td>
#       <td id="T_3f6ab_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3f6ab_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3f6ab_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_72e75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72e75_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_72e75_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_72e75_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_72e75_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_72e75_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_72e75_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72e75_row0_col0" class="data row0 col0" >0.2179</td>
#       <td id="T_72e75_row0_col1" class="data row0 col1" >332.9163</td>
#       <td id="T_72e75_row0_col2" class="data row0 col2" >1.4285</td>
#       <td id="T_72e75_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_72e75_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_72e75_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_44e9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44e9f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_44e9f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_44e9f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_44e9f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_44e9f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_44e9f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44e9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44e9f_row0_col0" class="data row0 col0" >0.1710</td>
#       <td id="T_44e9f_row0_col1" class="data row0 col1" >298.0764</td>
#       <td id="T_44e9f_row0_col2" class="data row0 col2" >1.5761</td>
#       <td id="T_44e9f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_44e9f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_44e9f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T
# <style type="text/css">
# </style>
# <table id="T_64f08" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64f08_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_64f08_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_64f08_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_64f08_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_64f08_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_64f08_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64f08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64f08_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_64f08_row0_col1" class="data row0 col1" >1.9448</td>
#       <td id="T_64f08_row0_col2" class="data row0 col2" >19.7566</td>
#       <td id="T_64f08_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_64f08_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_64f08_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_cb374" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb374_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cb374_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cb374_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cb374_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cb374_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cb374_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb374_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb374_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_cb374_row0_col1" class="data row0 col1" >1.7754</td>
#       <td id="T_cb374_row0_col2" class="data row0 col2" >16.7094</td>
#       <td id="T_cb374_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cb374_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cb374_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a4a0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4a0a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a4a0a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a4a0a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a4a0a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a4a0a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a4a0a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4a0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4a0a_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_a4a0a_row0_col1" class="data row0 col1" >1.6557</td>
#       <td id="T_a4a0a_row0_col2" class="data row0 col2" >16.4025</td>
#       <td id="T_a4a0a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a4a0a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a4a0a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using N+T+PCA
# <style type="text/css">
# </style>
# <table id="T_6fb34" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fb34_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6fb34_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6fb34_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6fb34_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6fb34_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6fb34_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fb34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fb34_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_6fb34_row0_col1" class="data row0 col1" >1.9448</td>
#       <td id="T_6fb34_row0_col2" class="data row0 col2" >19.7566</td>
#       <td id="T_6fb34_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6fb34_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6fb34_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_9406e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9406e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9406e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9406e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9406e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9406e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9406e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9406e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9406e_row0_col0" class="data row0 col0" >0.0009</td>
#       <td id="T_9406e_row0_col1" class="data row0 col1" >1.7754</td>
#       <td id="T_9406e_row0_col2" class="data row0 col2" >16.7094</td>
#       <td id="T_9406e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9406e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9406e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_c2089" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2089_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c2089_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c2089_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c2089_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c2089_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c2089_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2089_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2089_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_c2089_row0_col1" class="data row0 col1" >1.6557</td>
#       <td id="T_c2089_row0_col2" class="data row0 col2" >16.4025</td>
#       <td id="T_c2089_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c2089_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c2089_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pt2.field_names=["Parameters","No data preprocessing c=3","No data preprocessing c=4 ","No data preprocessing c=5","Using Normalisation c=3","Using Normalisation c=4","Using Normalisation c=5","Using Transform c=3","Using Transform c=4","Using Transform c=5","Using PCA c=3","Using PCA c=4","Using PCA c=5","Using N+T c=3","Using N+T c=4","Using N+T c=5","Using N+T+PCA c=3","Using N+T+PCA c=4","Using N+T+PCA c=5"]
pt2.add_row(["Silhouette",*svalues])
pt2.add_row(["Calinski-Harabasz",*cvalues])
pt2.add_row(["Davies-Bouldin",*dvalues])
print("USING HIERARCHIAL CLUSTERING")
print(pt2)
# Out:
# USING HIERARCHIAL CLUSTERING
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+
# |     Parameters    | No data preprocessing c=3 | No data preprocessing c=4  | No data preprocessing c=5 | Using Normalisation c=3 | Using Normalisation c=4 | Using Normalisation c=5 | Using Transform c=3 | Using Transform c=4 | Using Transform c=5 | Using PCA c=3 | Using PCA c=4 | Using PCA c=5 | Using N+T c=3 | Using N+T c=4 | Using N+T c=5 | Using N+T+PCA c=3 | Using N+T+PCA c=4 | Using N+T+PCA c=5 |
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+
# |     Silhouette    |           0.1298          |           0.0697           |           0.0607          |          0.002          |          0.0009         |          0.0008         |        0.1931       |        0.2179       |        0.171        |     0.1931    |     0.2179    |     0.171     |     0.0009    |     0.0009    |     0.0007    |       0.0009      |       0.0009      |       0.0007      |
# | Calinski-Harabasz |          141.6293         |          113.4169          |          98.4764          |          2.1931         |          1.9435         |          1.8057         |       344.3767      |       332.9163      |       298.0764      |    344.3767   |    332.9163   |    298.0764   |     1.9448    |     1.7754    |     1.6557    |       1.9448      |       1.7754      |       1.6557      |
# |   Davies-Bouldin  |           2.5243          |           2.9151           |           2.8817          |         14.3736         |         16.7015         |         16.0352         |        1.5753       |        1.4285       |        1.5761       |     1.5753    |     1.4285    |     1.5761    |    19.7566    |    16.7094    |    16.4025    |      19.7566      |      16.7094      |      16.4025      |
# +-------------------+---------------------------+----------------------------+---------------------------+-------------------------+-------------------------+-------------------------+---------------------+---------------------+---------------------+---------------+---------------+---------------+---------------+---------------+---------------+-------------------+-------------------+-------------------+

# %%
# To save output as .csv file
with open("hierarchial_output.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(pt2.field_names)
    for row in pt2._rows:
        writer.writerow(row)

# %% [markdown]
# **USING K-MEAN SHIFT CLUSTERING**

# %%
from pycaret.clustering import *
import pandas as pd
from prettytable import PrettyTable

pt3 = PrettyTable()
myDataSet = pd.read_csv("/content/tripadvisor_review.csv")
kMeanClusteringParameters = setup(data=myDataSet, verbose=False)

num_clusters = [3, 4, 5]
svalues = []
cvalues = []
dvalues = []

def get_parameters(num_clusters):
    model = create_model('meanshift', num_clusters=num_clusters)
    prediction = assign_model(model)
    performance = pull()
    svalues.append(performance['Silhouette'][0])
    cvalues.append(performance['Calinski-Harabasz'][0])
    dvalues.append(performance['Davies-Bouldin'][0])

def get_ans():
  for num in num_clusters:
    get_parameters(num)

print("For no data processing")
get_ans()
print("For using normalisation")
normparam = setup(data=myDataSet,normalize = True, normalize_method = 'zscore', verbose=False)
get_ans()
print("For using transform")
transformparam=setup(data=myDataSet,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using PCA")
pcaparam=setup(data=myDataSet,transformation = True,pca = True, pca_method = 'linear', verbose=False)
get_ans()
print("For using N+T")
ntparam=setup(data=myDataSet,transformation = True, normalize = True,normalize_method = 'zscore',
      transformation_method = 'yeo-johnson', verbose=False)
get_ans()
print("For using N+T+PCA")
ntpcaparam=setup(data=myDataSet,transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear',  verbose=False)
get_ans()
# Out:
# For no data processing
# <style type="text/css">
# </style>
# <table id="T_9bdef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bdef_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9bdef_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9bdef_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9bdef_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9bdef_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9bdef_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bdef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bdef_row0_col0" class="data row0 col0" >0.1836</td>
#       <td id="T_9bdef_row0_col1" class="data row0 col1" >23.3621</td>
#       <td id="T_9bdef_row0_col2" class="data row0 col2" >1.3692</td>
#       <td id="T_9bdef_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9bdef_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9bdef_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7fdb8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fdb8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7fdb8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7fdb8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7fdb8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7fdb8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7fdb8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fdb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fdb8_row0_col0" class="data row0 col0" >0.1836</td>
#       <td id="T_7fdb8_row0_col1" class="data row0 col1" >23.3621</td>
#       <td id="T_7fdb8_row0_col2" class="data row0 col2" >1.3692</td>
#       <td id="T_7fdb8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7fdb8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7fdb8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_7f35e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f35e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7f35e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7f35e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7f35e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7f35e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7f35e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f35e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f35e_row0_col0" class="data row0 col0" >0.1836</td>
#       <td id="T_7f35e_row0_col1" class="data row0 col1" >23.3621</td>
#       <td id="T_7f35e_row0_col2" class="data row0 col2" >1.3692</td>
#       <td id="T_7f35e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7f35e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7f35e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For using normalisation
# <style type="text/css">
# </style>
# <table id="T_76eb3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76eb3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_76eb3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_76eb3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_76eb3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_76eb3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_76eb3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76eb3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76eb3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_76eb3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_76eb3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_76eb3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_76eb3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_76eb3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               05:13:57
# Status     . . . . . . . . . . . . . . . . . .     Fitting 4 Clusters
# Estimator  . . . . . . . . . . . . . . . . . .  Mean Shift Clustering
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pt3.field_names=["Parameters","No data preprocessing c=3","No data preprocessing c=4 ","No data preprocessing c=5","Using Normalisation c=3","Using Normalisation c=4","Using Normalisation c=5","Using Transform c=3","Using Transform c=4","Using Transform c=5","Using PCA c=3","Using PCA c=4","Using PCA c=5","Using N+T c=3","Using N+T c=4","Using N+T c=5","Using N+T+PCA c=3","Using N+T+PCA c=4","Using N+T+PCA c=5"]
pt3.add_row(["Silhouette",*svalues])
pt3.add_row(["Calinski-Harabasz",*cvalues])
pt3.add_row(["Davies-Bouldin",*dvalues])
print("USING K-MEAN SHIFT CLUSTERING")
print(pt3)

# %%
# To save output as .csv file
with open("kmeansshift_output.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(pt3.field_names)
    for row in pt3._rows:
        writer.writerow(row)

# %% [markdown]
# # **Graphs for best models:**

# %% [markdown]
# **FOR K-MEAN CLUSTERING**

# %%
t_kmeans=setup(data=myDataSet,transformation = True, transformation_method = 'yeo-johnson', verbose=False)
KMeanModel = create_model('kmeans', num_clusters=4)
evaluate_model(KMeanModel)
plot_model(KMeanModel, plot='cluster')
plot_model(KMeanModel, plot='tsne')

# %% [markdown]
# **FOR HIERARCHIAL CLUSTERING**

# %%
hier=setup(data=myDataSet,transformation = True,pca = True, pca_method = 'linear', verbose=False)
hclustModel = create_model('hclust', num_clusters=4)
evaluate_model(hclustModel)
plot_model(hclustModel, plot='cluster')
plot_model(hclustModel, plot='tsne')

# %% [markdown]
# **FOR K-MEAN SHIFT CLUSTERING**

# %%
meanshift = setup(data=myDataSet, verbose=False)
meanshiftModel = create_model('meanshift', num_clusters=3)
evaluate_model(meanshiftModel)
plot_model(meanshiftModel, plot='cluster')
plot_model(meanshiftModel, plot='tsne')
